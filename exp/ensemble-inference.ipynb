# %%
import os
from glob import glob
import torch

class CFG_exp154:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '../input/debertav3base'
    BASE_PATH = '../input/exp154/exp154/'
    WEIGHT_PATH = '../input/exp154/exp154/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp159:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '../input/funneltransformermedium'
    BASE_PATH = '../input/exp159/exp159/'
    WEIGHT_PATH = '../input/exp159/exp159/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp160:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '../input/transformers/funnel-transformer-small'
    BASE_PATH = '../input/exp160/'
    WEIGHT_PATH = '../input/exp160/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp161:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 512
    batch_size = 8
    MODEL_PATH = '../input/transformers/roberta-base'
    BASE_PATH = '../input/exp161/exp161/'
    WEIGHT_PATH = '../input/exp161/exp161/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp163:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '../input/deberta-v3-large'
    BASE_PATH = '../input/exp163/exp163/'
    WEIGHT_PATH = '../input/exp163/exp163/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp170:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/deberta-v2-xlarge'
    BASE_PATH = '/kaggle/input/exp170/exp170/'
    WEIGHT_PATH = '/kaggle/input/exp170/exp170/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp171:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/deberta-v3-large'
    BASE_PATH = '/kaggle/input/exp171/exp171/'
    WEIGHT_PATH = '/kaggle/input/exp171/exp171/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp176:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/deberta-v3-small/deberta-v3-small'
    BASE_PATH = '/kaggle/input/exp176/exp176/'
    WEIGHT_PATH = '/kaggle/input/exp176/exp176/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp058:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 512
    batch_size = 8
    MODEL_PATH = '../input/debertav3base'
    BASE_PATH = '../input/feedback3-exp058-deberta-v3-base/'
    WEIGHT_PATH = '../input/feedback3-exp058-deberta-v3-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp060:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '../input/debertav3base'
    BASE_PATH = '/kaggle/input/feedback3-exp060-deberta-v3-base/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp060-deberta-v3-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))

class CFG_exp061:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/deberta-base'
    BASE_PATH = '/kaggle/input/feedback3-exp061-deberta-base/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp061-deberta-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp062:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/bartbase'
    BASE_PATH = '/kaggle/input/feedback3-exp062-bart-base/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp062-bart-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp063:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 1024
    batch_size = 8
    MODEL_PATH = '/kaggle/input/longformer-base-4096'
    BASE_PATH = '/kaggle/input/feedback3-exp063-lomgformer-base/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp063-lomgformer-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp064:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 512
    batch_size = 8
    MODEL_PATH = '/kaggle/input/google-electra-large-discriminator'
    BASE_PATH = '/kaggle/input/feedback3-exp064-electra-large/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp064-electra-large/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))
    
class CFG_exp065:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 768
    batch_size = 8
    MODEL_PATH = '/kaggle/input/debertav3base'
    BASE_PATH = '/kaggle/input/feedback3-exp065-deberta-v3-base/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp065-deberta-v3-base/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))

class CFG_exp066:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_len = 512
    batch_size = 8
    MODEL_PATH = '/kaggle/input/muppet-roberta-large'
    BASE_PATH = '/kaggle/input/feedback3-exp066-mup-roberta-large/'
    WEIGHT_PATH = '/kaggle/input/feedback3-exp066-mup-roberta-large/model'
    CONFIG_PATH = BASE_PATH + '/modelconfig.pth'
    model_prefix = 'baseline_'
    model_weights = glob(os.path.join(WEIGHT_PATH, '*.pth'))

# %%
import os
import gc
import re
import ast
import sys
import copy
import json
import time
import math
import shutil
import string
import pickle
import random
import joblib
import itertools
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

import torch
print(f"torch.__version__: {torch.__version__}")
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
from torch.optim import Adam, SGD, AdamW
from torch.utils.data import DataLoader, Dataset
from torch.cuda.amp import autocast, GradScaler

import tokenizers
import transformers
print(f"tokenizers.__version__: {tokenizers.__version__}")
print(f"transformers.__version__: {transformers.__version__}")
from transformers import AutoTokenizer, AutoModel, AutoConfig, ElectraModel, ElectraTokenizer, LongformerModel
from transformers import get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
from transformers import DataCollatorWithPadding
# %env TOKENIZERS_PARALLELISM=true
# Out:
# torch.__version__: 1.9.1
# tokenizers.__version__: 0.12.1
# transformers.__version__: 4.18.0
# env: TOKENIZERS_PARALLELISM=true

# %%
# =====================
# Dataset, Model
# =====================
from text_unidecode import unidecode
from typing import Dict, List, Tuple
import codecs

def replace_encoding_with_utf8(error: UnicodeError) -> Tuple[bytes, int]:
    return error.object[error.start : error.end].encode("utf-8"), error.end


def replace_decoding_with_cp1252(error: UnicodeError) -> Tuple[str, int]:
    return error.object[error.start : error.end].decode("cp1252"), error.end

# Register the encoding and decoding error handlers for `utf-8` and `cp1252`.
codecs.register_error("replace_encoding_with_utf8", replace_encoding_with_utf8)
codecs.register_error("replace_decoding_with_cp1252", replace_decoding_with_cp1252)

def resolve_encodings_and_normalize(text: str) -> str:
    """Resolve the encoding problems and normalize the abnormal characters."""
    text = (
        text.encode("raw_unicode_escape")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
        .encode("cp1252", errors="replace_encoding_with_utf8")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
    )
    text = unidecode(text)
    return text

def processing_features(df):
    df['text'] = df['full_text'].apply(lambda x : resolve_encodings_and_normalize(x))
    df['text'] = df['text'].apply(lambda x: x.rstrip())
    df['len_text'] = df['text'].apply(lambda x: len(x.split()))
    df = df.sort_values('len_text').reset_index(drop=True)
    return df

# %%
# dataset
class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.texts = df['text'].to_numpy()

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        inputs = self.prepare_input(self.cfg, self.texts[index])
        return inputs

    @staticmethod
    def prepare_input(cfg, text):
        inputs = cfg.tokenizer(text, 
                               add_special_tokens=True,
                               max_length=cfg.max_len,
                               padding="max_length",
                               truncation=True,
                               return_offsets_mapping=False)
        
        for k, v in inputs.items():
            inputs[k] = torch.tensor(v, dtype=torch.long)
        
        return inputs
    
def collate(inputs):
    mask_len = int(inputs["attention_mask"].sum(axis=1).max())
    for k, v in inputs.items():
        inputs[k] = inputs[k][:,:mask_len]
    return inputs

# %%
class AttentionPooling(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.attention = nn.Sequential(
        nn.Linear(in_dim, in_dim),
        nn.LayerNorm(in_dim),
        nn.GELU(),
        nn.Linear(in_dim, 1),
        )
        
        self._init_weights(self.attention)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def forward(self, last_hidden_state, attention_mask):
        w = self.attention(last_hidden_state).float()
        w[attention_mask==0]=float('-inf')
        w = torch.softmax(w,1)
        attention_embeddings = torch.sum(w * last_hidden_state, dim=1)
        return attention_embeddings
    
class MeanPooling(nn.Module):
    def __init__(self):
        super(MeanPooling, self).__init__()
    def forward(self, last_hidden_state, attention_mask):
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min = 1e-9)
        mean_embeddings = sum_embeddings/sum_mask
        return mean_embeddings

class WeightedLayerPooling(nn.Module):
    def __init__(self, num_hidden_layers, layer_start: int = 4, layer_weights = None):
        super(WeightedLayerPooling, self).__init__()
        self.layer_start = layer_start
        self.num_hidden_layers = num_hidden_layers
        self.layer_weights = layer_weights if layer_weights is not None \
            else nn.Parameter(
                torch.tensor([1] * (num_hidden_layers+1 - layer_start), dtype=torch.float)
            )
    def forward(self, ft_all_layers):
        all_layer_embedding = torch.stack(ft_all_layers)
        all_layer_embedding = all_layer_embedding[self.layer_start:, :, :, :]
        weight_factor = self.layer_weights.unsqueeze(-1).unsqueeze(-1).unsqueeze(-1).expand(all_layer_embedding.size())
        weighted_average = (weight_factor*all_layer_embedding).sum(dim=0) / self.layer_weights.sum()
        return weighted_average

class Exp154Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp159Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp160Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp161Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp163Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp170Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.weighted_layer_pool = WeightedLayerPooling(self.config.num_hidden_layers)
        self.pool = MeanPooling()
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)
            
    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        all_layer_embeddings = outputs[1]
        feature = self.weighted_layer_pool(all_layer_embeddings)
        feature = self.pool(feature, inputs['attention_mask'])
        return feature
    
    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp171Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp176Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.model = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp058Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )

        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
# 参考：https://github.com/Danielhuxc/CLRP-solution/blob/main/components/model.py
class Exp060Model(nn.Module):
    def __init__(self, cfg): 
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )

        # self.dropout = nn.Dropout(p=0.2)
        # self.high_dropout = nn.Dropout(p=0.5)

        weights_init = torch.zeros(4).float()
        self.layer_weights = torch.nn.Parameter(weights_init)

        self.head = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.head)
        
        self.attention = AttentionPooling(self.config.hidden_size)
        
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)

        # 4層を重ねる
        stack_outputs = torch.stack(
            [layer for layer in outputs.hidden_states[-4:]], dim=0
        )

        # 重み付け平均（batch, length, hidden_size）
        weighted_output = (torch.softmax(self.layer_weights, dim=0).unsqueeze(1).unsqueeze(1).unsqueeze(1) * stack_outputs).sum(0)

        # 重み付け平均をattentionかける(batch, hidden_size)
        feature = self.attention(weighted_output, inputs['attention_mask'])

        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.head(self.ln(feature))
        return output
    
    
class Exp061Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )

        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp062Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )

        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output

class Exp063Model(nn.Module):
    def __init__(self, cfg): 
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = LongformerModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp064Model(nn.Module):
    def __init__(self, cfg): 
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = ElectraModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output
    
class Exp065Model(nn.Module):
    def __init__(self, cfg): 
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )
        self.fc = nn.Linear(self.config.hidden_size*4, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.2)
        self.dropout3 = nn.Dropout(0.3)
        self.dropout4 = nn.Dropout(0.4)
        self.dropout5 = nn.Dropout(0.5)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def forward(self, inputs):
        # batch, hidden_size
        bert_outputs = self.backbone(**inputs)
        # 最終4層をconcatenate
        cls = torch.cat([bert_outputs["hidden_states"][-1*i][:, 0] for i in range(1, 4+1)], dim=1)
        logits1 = self.fc(self.dropout1(cls))
        logits2 = self.fc(self.dropout2(cls))
        logits3 = self.fc(self.dropout3(cls))
        logits4 = self.fc(self.dropout4(cls))
        logits5 = self.fc(self.dropout5(cls))
        output = (logits1 + logits2 + logits3 + logits4 + logits5) / 5
        
        return output
    
    
class Exp066Model(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.config.update(
            {
                "output_hidden_states": True,
                "hidden_dropout": 0.,
                "hidden_dropout_prob": 0.,
                "attention_dropout": 0.,
                "attention_probs_dropout_prob": 0,
            }
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH,
            config=self.config
        )

        self.pool = AttentionPooling(self.config.hidden_size)
        self.fc = nn.Linear(self.config.hidden_size, 6)
        self._init_weights(self.fc)
        self.ln = nn.LayerNorm(self.config.hidden_size)
        self._init_weights(self.ln)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def feature(self, inputs):
        outputs = self.backbone(**inputs)
        last_state = outputs[0]
        feature = self.pool(last_state, inputs['attention_mask'])
        return feature

    def forward(self, inputs):
        # batch, hidden_size
        feature = self.feature(inputs)
        output = self.fc(self.ln(feature))
        return output

# %%
def inferring(cfg, test, custom_model):
    sub_pred = np.zeros((len(test), 6), dtype=np.float32)
    
    for model_weight in cfg.model_weights:
        # dataset, dataloader
        test_dataset = TestDataset(cfg, test)
        test_loader = DataLoader(
            dataset=test_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=False,
            pin_memory=True,
            num_workers=2,
            # collate_fn = DataCollatorWithPadding(tokenizer=cfg.tokenizer, padding='longest', max_length = cfg.max_len)
        )
        
        # model
        model = custom_model(cfg)
        model.load_state_dict(torch.load(model_weight))
        model = model.to(cfg.device)
        
        # evaluation
        model.eval()
        tmp_pred = []
        with torch.no_grad():
            for inputs in tqdm(test_loader, total=len(test_loader)):
                inputs = collate(inputs)
                for k, v in inputs.items():
                    inputs[k] = v.to(cfg.device)
                with autocast():
                    output = model(inputs)
                output = output.detach().cpu().numpy()
                tmp_pred.append(output)
        tmp_pred = np.concatenate(tmp_pred)
        sub_pred = sub_pred + tmp_pred / len(cfg.model_weights)
        
        del model, tmp_pred; gc.collect()
        torch.cuda.empty_cache()

    return sub_pred

# %%
# =====================
# Main
# =====================
test = pd.read_csv('../input/feedback-prize-english-language-learning/test.csv')
submission = pd.read_csv('../input/feedback-prize-english-language-learning/sample_submission.csv')

test = processing_features(test)

exp_ensemble = []
    
for (cfg_model, custmom_model) in [
    (CFG_exp154, Exp154Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp159, Exp159Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp160, Exp160Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp161, Exp161Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp163, Exp163Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp170, Exp170Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp171, Exp171Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp176, Exp176Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp058, Exp058Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp060, Exp060Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp061, Exp061Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp062, Exp062Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp063, Exp063Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp064, Exp064Model),]:
    cfg_model.tokenizer = ElectraTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp065, Exp065Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
    
for (cfg_model, custmom_model) in [
    (CFG_exp066, Exp066Model),]:
    cfg_model.tokenizer = AutoTokenizer.from_pretrained(cfg_model.BASE_PATH + 'tokenizer/')
    exp_pred = inferring(cfg_model, test, custmom_model)
    exp_ensemble.append(exp_pred)
# Out:
# Some weights of the model checkpoint at ../input/debertav3base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.dense.bias', 'mask_predictions.dense.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.LayerNorm.weight', 'mask_predictions.LayerNorm.bias', 'mask_predictions.classifier.bias', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.bias', 'mask_predictions.classifier.weight']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
weight = np.load('../input/feedback3-weight-nelder-mead/moa_weight.npy')
predictions = np.average(np.array(exp_ensemble), axis=0, weights = weight)

# %%
target_cols=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
test[target_cols] = predictions
submission = submission.drop(columns=target_cols).merge(test[['text_id'] + target_cols], on='text_id', how='left')
display(submission.head())
submission[['text_id'] + target_cols].to_csv('submission.csv', index=False)
# Out:
#         text_id  cohesion    syntax  vocabulary  phraseology   grammar  conventions
# 0  0000C359D63E  2.869795  2.747047    3.080803     2.930335  2.631613     2.640493
# 1  000BAD50D026  2.650898  2.475199    2.724987     2.393050  2.143764     2.632653
# 2  00367BB2546B  3.680709  3.442308    3.631753     3.609067  3.420098     3.314930
